# %% [markdown]
# # Making N1 connections for Neo4j Import

# %%
import sys
sys.path.append('../py')
import sparql_tools as qt
import processing as pt

import pandas as pd
from tqdm import tqdm

# %%
comp = pd.read_hdf('data/compound_edges.h5')
gene = pd.read_hdf('data/h_genes_edges.h5')
prot = pd.read_hdf('data/h_protein_edges.h5')
dis = pd.read_hdf('data/disease_edges.h5')

# %%
comp['type'] = 'Compound'
gene['type'] = 'Gene'
prot['type'] = 'Protein'
dis['type'] = 'Disease'

# %% [markdown]
# ## Split Genes into multiple types
#
# Rationale:
#
# - Using a subclass of link for all these subtypes would add more nodes and edges to the graph
# - Since learning performance is dependant of path lenght, having this information encoded in the node_type will
# reduce the path length
# - Almost all genes have 2 types (56,500 / 60,000) so it makes sense to separate these types out.

# %%
gene_types = pt.combine_multiclass(gene, edge_type='subclass of', sep='; ')

# %%
gene_types['label'].value_counts()
# Out:
# gene; protein-coding gene                    20700
# gene; non-coding RNA                         18064
# gene; pseudogene                             16861
# gene                                          3447
# gene; transfer RNA                             553
# gene; small nucleolar RNA                      431
# gene; small nuclear RNA                         63
# gene; ribosomal RNA                             39
# gene; non-coding RNA; protein-coding gene        2
# gene; protein-coding gene; pseudogene            1
# Name: label, dtype: int64

# %% [markdown]
# Lets use 4 main categories:
#
#  - Gene
#  - Protein-coding gene
#  - Non-coding RNA
#  - Psuedogene
#
# tRNA and small nucleolar RNA may be large enough to try, too, but at first pass we're going to stick with these 4
#
# In terms of hiearachry, protein-coding > Non-coding > psuedogene > Gene

# %%
def categorize_func(item):
    if 'protein-coding gene' in item:
        return 'Protein-coding Gene'
    elif 'non-coding RNA'in item:
        return 'Non-coding RNA'
    elif 'pseudogene' in item:
        return 'Pseudogene'
    else:
        return 'Gene'

# %%
gene_types['label'] = gene_types['label'].apply(categorize_func)

# %%
gene_types['label'].value_counts()
# Out:
# Protein-coding Gene    20703
# Non-coding RNA         18064
# Pseudogene             16861
# Gene                    4533
# Name: label, dtype: int64

# %%
gene_type_dict = pt.get_node_type_dict(gene_types)
gene['type'] = gene['s'].apply(lambda s: gene_type_dict[s])

base = pd.concat([comp, gene, prot, dis])
base['type'].value_counts()
# Out:
# Protein                495113
# Compound               190386
# Protein-coding Gene    162902
# Non-coding RNA          65856
# Pseudogene              52178
# Disease                 29447
# Gene                    11181
# Name: type, dtype: int64

# %% [markdown]
# ## Filter out Low Count Edges

# %% [markdown]
# ## Look at N1 Nodes

# %%
n1 = pd.read_hdf('data/n1_edges.h5')

# %%
n1_filt = pt.filter_bad(n1)

# %%
de = ['biological process', 'cell component', 'molecular function', 'found in taxon', 'chromosome', 'strand orientation']

# %% [markdown]
# ### Assign types with descriptive egdes

# %%
de_map = {
    'biological process': 'GO Term',
    'cell component': 'GO Term',
    'molecular function': 'GO Term',
    'found in taxon': 'Taxon',
    'chromosome': 'Chromosome',
    'strand orientation': 'Strand Orientation'
   }
mapping_dict = dict()
for edge, etype in de_map.items():
    found = base.query('pLabel == {!r}'.format(edge)).reset_index(drop=True)
    found['type'] = etype 
    mapping_dict.update(found.set_index('o')['type'].to_dict())

# %% [markdown]
# ### Assign types to remining nodes
#
# - Start with 'instance of'
# - next do 'subclass of' and 'found in taxon'
#     - Doing both will separte genes and proteins by taxon

# %%
n1_types = pt.combine_multiclass(n1_filt)
n1_dict = pt.get_node_type_dict(n1_types)

# %%
n1_types1 = pt.combine_multiclass(n1_filt, edge_type=['subclass of', 'found in taxon'])
n1_dict1 = pt.get_node_type_dict(n1_types1)

# %%
n1_dict1.update(n1_dict)

# %%
n1_dict1.update(mapping_dict)

# %%
n1_filt['type'] = n1_filt['s'].apply(lambda s: n1_dict1[s] if s in n1_dict1 else 'Other')

# %%
n1_filt['type'].value_counts()[:15]
# Out:
# mature microRNA                                              292164
# Mus musculus; gene; protein-coding gene                      136320
# brown rat; gene; protein-coding gene                         121899
# GO Term                                                       44584
# chemical hazard                                               15328
# protein family                                                13970
# protein domain                                                13351
# Saccharomyces cerevisiae S288c; gene; protein-coding gene     11915
# human                                                          3258
# Supersecondary structure                                       2023
# Other                                                          1408
# taxon                                                           563
# active site                                                     414
# encyclopedia                                                    408
# Structural motif                                                357
# Name: type, dtype: int64

# %% [markdown]
# ## Combine Base and N1 node edges

# %%
base_filt = pt.filter_bad(base)
full_list = pd.concat([base_filt, n1_filt]).reset_index(drop=True)

# %%
neo_nodes = pt.nodes_neo_export(full_list)

# %%
neo_edges = pt.edges_neo_export(full_list)

# %%
len(neo_nodes)
# Out:
# 323086

# %%
len(neo_edges)
# Out:
# 1578644

# %%
neo_nodes[':LABEL'].nunique()
# Out:
# 1098

# %%
neo_nodes[':LABEL'].value_counts()[:30]
# Out:
# Compound                                                     156692
# Protein                                                       26706
# Protein-coding Gene                                           20703
# Non-coding RNA                                                18064
# GO Term                                                       17281
# Mus musculus; gene; protein-coding gene                       17096
# Pseudogene                                                    16861
# brown rat; gene; protein-coding gene                          16564
# Disease                                                        8785
# protein family                                                 7187
# Gene                                                           4533
# protein domain                                                 4245
# mature microRNA                                                2285
# Saccharomyces cerevisiae S288c; gene; protein-coding gene      1332
# Other                                                           981
# chemical hazard                                                 596
# Supersecondary structure                                        463
# human                                                           244
# taxon                                                           129
# Structural motif                                                115
# active site                                                      92
# chemical compound                                                85
# Binding site                                                     57
# anatomical structure                                             54
# medical specialty                                                50
# chemical substance                                               42
# symptom                                                          40
# chemical element                                                 37
# Mus musculus; gene; pseudogene                                   32
# Chromosome                                                       25
# Name: :LABEL, dtype: int64

# %%
neo_edges[':TYPE'].nunique()
# Out:
# 4442

# %%
neo_edges[':TYPE'].value_counts()[:100]
# Out:
# regulates-(molecular-biology)_MMrPG    278713
# instance-of_CiCS                       156788
# biological-process_PbGT                153189
# cell-component_PcGT                     96891
# molecular-function_PmGT                 81543
# has-part_PhPD                           49916
# found-in-taxon_PfT                      43568
# subclass-of_PsBN                        25042
# encodes_PGeP                            24668
# encoded-by_PePG                         24519
# subclass-of_GTsGT                       20744
# subclass-of_PGsG                        20702
# found-in-taxon_PGfT                     20702
# subclass-of_PGsNAS                      20702
# chromosome_PGcC                         19293
# strand-orientation_PGsSO                19256
# subclass-of_NRsR                        18069
# subclass-of_NRsNAS                      18064
# found-in-taxon_NRfT                     18064
# ortholog_PGoMMGPG                       17218
# ortholog_MMGPGoPG                       17143
# found-in-taxon_MMGPGfT                  17096
# subclass-of_MMGPGsNAS                   17096
# subclass-of_MMGPGsG                     17096
# ortholog_MMGPGoBRGPG                    16983
# ortholog_BRGPGoMMGPG                    16969
# strand-orientation_MMGPGsSO             16951
# subclass-of_PsNAS                       16865
# subclass-of_PsO                         16861
# ortholog_PGoBRGPG                       16680
#                                         ...
# significant-drug-interaction_CsC         1798
# instance-of_PiNR                         1665
# subclass-of_PFsPF                        1470
# ortholog_PGoSCSGPG                       1336
# ortholog_BRGPGoSCSGPG                    1332
# subclass-of_SCSGPGsG                     1332
# strand-orientation_SCSGPGsSO             1332
# subclass-of_SCSGPGsNAS                   1332
# ortholog_MMGPGoSCSGPG                    1327
# ortholog_SCSGPGoPG                       1324
# ortholog_SCSGPGoBRGPG                    1320
# ortholog_SCSGPGoMMGPG                    1315
# found-in-taxon_CfT                       1231
# symptoms_CHsS                            1220
# symptoms_CHsD                            1171
# has-part_PhAS                            1143
# subclass-of_GsNR                         1047
# has-part_PhBS                             927
# regulates-(molecular-biology)_MMrP        908
# subclass-of_PDsPD                         894
# has-part_PFhSS                            684
# part-of_SSpPF                             684
# regulates-(molecular-biology)_MMrNR       608
# has-part_ChCEG1P1S                        607
# cause-of_CcCH                             596
# has-cause_CHhC                            594
# afflicts_CHaCNDIUAU                       584
# afflicts_CHaAS                            553
# route-of-administration_CHrROA            515
# has-part_PDhPD                            490
# Name: :TYPE, dtype: int64

# %%
edges_to_keep = []
for edge, count in neo_edges[':TYPE'].value_counts().to_dict().items():
    if count > .001*len(neo_edges):
        edges_to_keep.append(edge)

# %%
len(edges_to_keep)
# Out:
# 72

# %%
neo_nodes[':LABEL'].value_counts().to_csv('data/node_types_counts.csv')

# %%
neo_edges[':TYPE'].value_counts().to_csv('data/edge_types_counts.csv')

# %%
neo_nodes.to_csv('data/neo_nodes_n1.csv', index=False)

# %%
neo_edges.to_csv('data/neo_edges_n1.csv', index=False)

# %% [markdown]
# ## Get types for all S and O uris

# %%
# Filter out o's that aren't in the S set.

s_set = set(full_list['s'])
full_list1 = full_list.query('o in {}'.format(list(s_set)))

# %%
# Get the types already assinged to 's' values in a dict
test_dict = {row['s']: row['type'] for x, row in full_list1.iterrows()}
test_dict.update(n1_dict1)

# %% [markdown]
# #### Make a DataFrame of source node type, edge, and target node type

# %%
def edge_to_edge_type(row):
    from_type = test_dict.get(row['s'], 'Other')
    to_type = test_dict.get(row['o'], 'Other')
    
    e_type = row['pLabel']
    
    return [from_type, e_type, to_type]

# %%
type_df = pd.DataFrame()

# %%
# %%time
type_series = full_list1.apply(edge_to_edge_type, axis = 1)
# Out:
# CPU times: user 1min 24s, sys: 52 ms, total: 1min 24s
# Wall time: 1min 24s

# %%
type_df[['start', 'edge', 'end']] = pd.DataFrame([x for x in type_series])

# %%
len(type_df)
# Out:
# 1578644

# %%
node_info = neo_nodes[':LABEL'].value_counts().to_frame()
node_info.columns = ['count']

# %%
node_info['edge_count'] = type_df['start'].value_counts()
node_info['edge_count'] += type_df['end'].value_counts()
node_info['edge_count'] = node_info['edge_count'].fillna(0).astype(int)
node_info['edge_per_node'] = node_info['edge_count'].astype(float) / node_info['count'].astype(float)
#node_info = node_info[:50]

# %%
gene_types_list = list(set(gene_types['label']))

# %%
def count_type(row, e_type):
    idx = row.name
    count = len(type_df.query('(start == "{0}" and end == "{1}") | (start == "{1}" and end == "{0}")'.format(idx, e_type)))
    return count

# %%
def count_gene_links(row):
    idx = row.name
    count = len(type_df.query('(start == "{0}" and end in {1}) | (start in {1} and end == "{0}")'.format(idx, gene_types_list)))
    return count

# %%
# %%time
node_info['comp_links'] = node_info.apply(lambda row: count_type(row, 'Compound'), axis = 1)
node_info['gene_links'] = node_info.apply(count_gene_links, axis = 1)
node_info['prot_links'] = node_info.apply(lambda row: count_type(row, 'Protein'), axis = 1)
node_info['dis_links'] = node_info.apply(lambda row: count_type(row, 'Disease'), axis = 1)
# Out:
# CPU times: user 25min 2s, sys: 248 ms, total: 25min 2s
# Wall time: 24min 46s

# %%
node_info.head()
# Out:
#                       count  edge_count  edge_per_node  comp_links  \
# Compound             156692      203118       1.296288        4368
# Protein               26706      528464      19.788212        7258
# Protein-coding Gene   20703      503434      24.316959           4
# Non-coding RNA        18064       68349       3.783713           0
# GO Term               17281      399548      23.120653          56
#
#                      gene_links  prot_links  dis_links
# Compound                     43        7258       5750
# Protein                   54172          16         17
# Protein-coding Gene           0       49191       4343
# Non-coding RNA                0        3733         41
# GO Term                       0      331603         22

# %%
node_info['basenode_links'] = node_info['comp_links'] + node_info['gene_links'] + node_info['prot_links'] + node_info['dis_links']
node_info['basenode_fract'] = node_info['basenode_links'].astype(float) / node_info['edge_count'].astype(float)
node_info['basenode_prop'] = node_info['basenode_links'].astype(float) / node_info['count'].astype(float)

# %%
node_info.head(20)
# Out:
#                                                      count  edge_count  \
# Compound                                            156692      203118
# Protein                                              26706      528464
# Protein-coding Gene                                  20703      503434
# Non-coding RNA                                       18064       68349
# GO Term                                              17281      399548
# Mus musculus; gene; protein-coding gene              17096      139489
# Pseudogene                                           16861       53542
# brown rat; gene; protein-coding gene                 16564      134971
# Disease                                               8785       46817
# protein family                                        7187       32936
# Gene                                                  4533       11475
# protein domain                                        4245       61553
# mature microRNA                                       2285      292309
# Saccharomyces cerevisiae S288c; gene; protein-c...    1332       11954
# Other                                                  981       19026
# chemical hazard                                        596        8069
# Supersecondary structure                               463        6641
# human                                                  244        1094
# taxon                                                  129         340
# Structural motif                                       115        2857
#
#                                                     edge_per_node  comp_links  \
# Compound                                                 1.296288        4368
# Protein                                                 19.788212        7258
# Protein-coding Gene                                     24.316959           4
# Non-coding RNA                                           3.783713           0
# GO Term                                                 23.120653          56
# Mus musculus; gene; protein-coding gene                  8.159160           0
# Pseudogene                                               3.175494           0
# brown rat; gene; protein-coding gene                     8.148454           0
# Disease                                                  5.329197        5750
# protein family                                           4.582719           1
# Gene                                                     2.531436          39
# protein domain                                          14.500118           5
# mature microRNA                                        127.925164           0
# Saccharomyces cerevisiae S288c; gene; protein-c...       8.974474           0
# Other                                                   19.394495         708
# chemical hazard                                         13.538591        1244
# Supersecondary structure                                14.343413           0
# human                                                    4.483607          83
# taxon                                                    2.635659          23
# Structural motif                                        24.843478           0
#
#                                                     gene_links  prot_links  \
# Compound                                                    43        7258
# Protein                                                  54172          16
# Protein-coding Gene                                          0       49191
# Non-coding RNA                                               0        3733
# GO Term                                                      0      331603
# Mus musculus; gene; protein-coding gene                  34372          46
# Pseudogene                                                   0         896
# brown rat; gene; protein-coding gene                     33341           3
# Disease                                                   4402          17
# protein family                                               0       14296
# Gene                                                         0         352
# protein domain                                               0       49930
# mature microRNA                                         280347        4934
# Saccharomyces cerevisiae S288c; gene; protein-c...        2660           0
# Other                                                    16867          11
# chemical hazard                                              2           0
# Supersecondary structure                                     0        4370
# human                                                        0           1
# taxon                                                        0           0
# Structural motif                                             0        2466
#
#                                                     dis_links  basenode_links  \
# Compound                                                 5750           17419
# Protein                                                    17           61463
# Protein-coding Gene                                      4343           53538
# Non-coding RNA                                             41            3774
# GO Term                                                    22          331681
# Mus musculus; gene; protein-coding gene                     0           34418
# Pseudogene                                                 16             912
# brown rat; gene; protein-coding gene                        0           33344
# Disease                                                 10440           20609
# protein family                                              0           14297
# Gene                                                        2             393
# protein domain                                              0           49935
# mature microRNA                                             0          285281
# Saccharomyces cerevisiae S288c; gene; protein-c...          0            2660
# Other                                                     767           18353
# chemical hazard                                          1298            2544
# Supersecondary structure                                    0            4370
# human                                                     227             311
# taxon                                                     258             281
# Structural motif                                            0            2466
#
#                                                     basenode_fract  \
# Compound                                                  0.085758
# Protein                                                   0.116305
# Protein-coding Gene                                       0.106346
# Non-coding RNA                                            0.055217
# GO Term                                                   0.830141
# Mus musculus; gene; protein-coding gene                   0.246743
# Pseudogene                                                0.017033
# brown rat; gene; protein-coding gene                      0.247046
# Disease                                                   0.440203
# protein family                                            0.434084
# Gene                                                      0.034248
# protein domain                                            0.811252
# mature microRNA                                           0.975957
# Saccharomyces cerevisiae S288c; gene; protein-c...        0.222520
# Other                                                     0.964627
# chemical hazard                                           0.315281
# Supersecondary structure                                  0.658033
# human                                                     0.284278
# taxon                                                     0.826471
# Structural motif                                          0.863143
#
#                                                     basenode_prop
# Compound                                                 0.111167
# Protein                                                  2.301468
# Protein-coding Gene                                      2.586002
# Non-coding RNA                                           0.208924
# GO Term                                                 19.193392
# Mus musculus; gene; protein-coding gene                  2.013219
# Pseudogene                                               0.054089
# brown rat; gene; protein-coding gene                     2.013040
# Disease                                                  2.345931
# protein family                                           1.989286
# Gene                                                     0.086698
# protein domain                                          11.763251
# mature microRNA                                        124.849453
# Saccharomyces cerevisiae S288c; gene; protein-c...       1.996997
# Other                                                   18.708461
# chemical hazard                                          4.268456
# indirect transmission                                          inf
# hyperimmunoglobulin syndrome                              0.857143
# calcium metabolism disease; disorder of magnesi...        1.000000
# national encyclopedia; universal encyclopedia                  inf
# Somatosensory disorder                                         inf
# Reaction inhibitor                                             inf
# bacterial infectious disease; disease                     0.962963
# lymphangioma                                              1.000000
# myositis                                                  0.944444
# parasite                                                  1.000000
# drug; product                                             0.982999
# ulcerative stomatitis                                     1.000000
# duct                                                           inf
# carcinogen                                                0.971154
# reading disorder                                          1.000000
# emotion; perception                                       0.812500
# active ingredient                                         1.000000
# class                                                          inf
# GPCR, family 3                                            0.857143
# retinal degeneration                                      1.000000
# generalized epilepsy                                      1.000000
# penile disease                                            1.000000
# heart valve disease                                       1.000000
# disease; spinal muscular atrophy                          0.833333
# Alzheimer's disease; early-onset diseases                 0.937500
# hepatobiliary disease                                     1.000000
# carcinoma; disease; gastrointestinal system can...        0.875000
# paroxysmal tachycardia; supraventricular arrhyt...        0.914286
# tongue disease                                            1.000000
# nutritional deficiency disease                            1.000000
#
#                                                     basenode_prop
# GO Term                                                 19.193392
# protein domain                                          11.763251
# mature microRNA                                        124.849453
# Other                                                   18.708461
# taxon                                                    2.178295
# Structural motif                                        21.443478
# medical specialty                                       40.640000
# chemical substance                                    3735.119048
# chemical element                                       188.189189
# Chromosome                                            1093.680000
# pharmaceutical drug                                     22.130435
# Wikimedia permanent duplicated page                      1.900000
# pandemic                                                 2.000000
# kampo formula                                            2.000000
# flammable liquid                                        35.714286
# crystal system                                          43.428571
# Australian pregnancy category                            2.857143
# scientific article                                       1.500000
# epidemic                                                 2.000000
# diagnostic procedure                                     1.200000
# health problem                                        1773.000000
# US pregnancy category                                    7.400000
# non-coding RNA                                         542.800000
# color; primary color                                    35.000000
# mutation                                                 1.600000
# nervous system disease                                   4.000000
# epithelial sodium channel                                1.250000
# parasitic protozoa infectious disease                    2.000000
# genetic disease                                          4.000000
# chemical element; gas                                 1075.666667
# ...                                                           ...
# indirect transmission                                    2.000000
# hyperimmunoglobulin syndrome                             6.000000
# calcium metabolism disease; disorder of magnesi...       2.000000
# national encyclopedia; universal encyclopedia          413.000000
# Somatosensory disorder                                   2.000000
# Reaction inhibitor                                       2.000000
# bacterial infectious disease; disease                   26.000000
# lymphangioma                                             2.000000
# myositis                                                17.000000
# parasite                                                 2.000000
# drug; product                                         2255.000000
# ulcerative stomatitis                                    3.000000
# duct                                                     2.000000
# carcinogen                                             101.000000
# reading disorder                                         3.000000
# emotion; perception                                    195.000000
# active ingredient                                        2.000000
# class                                                    3.000000
# GPCR, family 3                                           6.000000
# retinal degeneration                                     4.000000
# generalized epilepsy                                     3.000000
# penile disease                                           2.000000
# heart valve disease                                      4.000000
# disease; spinal muscular atrophy                         5.000000
# Alzheimer's disease; early-onset diseases               15.000000
# hepatobiliary disease                                    3.000000
# carcinoma; disease; gastrointestinal system can...       7.000000
# paroxysmal tachycardia; supraventricular arrhyt...      32.000000
# tongue disease                                           2.000000
# nutritional deficiency disease                           2.000000
#
# [228 rows x 10 columns]
