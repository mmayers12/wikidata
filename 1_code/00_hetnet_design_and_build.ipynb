# %%
import os
import json
import pandas as pd

# %% [markdown]
# ## Define Nodes

# %%
node_info = {}

# There seem to be many types of sequence variants,
# But the edges that link them are pretty unique, so will define based on
# Those edges rather than a Q-ID
node_info['Sequence Variant'] = {
    'abbrev': 'V',
    'id': None}

node_info['Binding Site'] = {
    'abbrev': 'BS',
    'id': 'Q616005'}

node_info['Active Site'] = {
    'abbrev': 'AS',
    'id': 'Q423026'}

node_info['Super-Secondary Structure'] = {
    'abbrev': 'SS',
    'id': 'Q7644128'}

node_info['Chemical Hazard'] = {
    'abbrev': 'CH',
    'id': 'Q21167512'}

node_info['Molecular Function'] = {
    'abbrev': 'MF',
    'id': 'Q14860489'}
    
node_info['Pharmaceutical Product'] = {
    'abbrev': 'PP',
    'id': 'Q28885102'}

node_info['Structural Motif'] = {
    'abbrev': 'SM',
    'id': 'Q3273544'}

node_info['Protein Family'] = {
    'abbrev': 'PF',
    'id': 'Q417841'}

node_info['Compound'] = {
    'abbrev': 'C',
    'id': 'Q11173'}

node_info['Disease'] = {
    'abbrev': 'D',
    'id': 'Q12136'}

## All proteins are encoded by genes, so qualify with 'gene encodes protein'
node_info['Protein'] = {
    'abbrev': 'P',
    'id': 'Q8054',
    'qualifiers': [{'s': 'Gene', 'p': 'P688', 'o': 'Protein', 'not': False},
                   {'s': 'Gene', 'p': 'P703', 'o': 'Q15978631', 'not': False}]}

## Genes will be defined as a human gene that does not encode a ANYTHING
## None in Object means it only cares about P688.... (if you specifiy proteins, get memory erros...)
node_info['Gene'] = {
    'abbrev': 'G',
    'id': 'Q7187',
    'qualifiers': [{'s': 'Gene', 'p': 'P688', 'o': None, 'not': True}, 
                   {'s': 'Gene', 'p': 'P703', 'o': 'Q15978631', 'not': False}]}
    
node_info['Protein Domain'] = {
    'abbrev': 'PD',
    'id': 'Q898273'}
    
node_info['Cellular Component'] = {
    'abbrev': 'CC',
    'id': 'Q5058355'}
    
node_info['Biological Pathway'] = {
    'abbrev': 'PW',
    'id': 'Q4915012'}

node_info['Biological Process'] = {
    'abbrev': 'BP',
    'id': 'Q2996394'}

# Don't want symptoms that could also be diseases....
# Get a lot of overlapping types espectially on chemcial hazard edges
node_info['Symptom'] = {
    'abbrev': 'S',
    'id': 'Q169872',
    'qualifiers': [{'s': 'Symptom', 'p': 'P31', 'o': 'Q12136', 'not': True},
                   {'s': 'Symptom', 'p': 'P279', 'o': 'Q12136', 'not': True}]}
    
node_info['Medical Specialty'] = {
    'abbrev': 'MS',
    'id': 'Q930752'}

# Chemical Role doesn't exist, but is an important type....
# Again defining based on the edge
node_info['Chemical Role'] = {
    'abbrev': 'CR',
    'id': None}
    
node_info['Anatomical Structure'] = {
    'abbrev': 'A',
    'id': 'Q4936952'}

# %%
edge_info = {}

edge_info['BIOLOGICAL_PROCESS'] = {
    'abbrev': 'bp',
    'id': 'P682'}

edge_info['VARIANT_OF'] = {
    'abbrev': 'v',
    'id': 'P3433'}

edge_info['CELL_COMPONENT'] = {
    'abbrev': 'cc',
    'id': 'P681'}

edge_info['TREATS'] = {
    'abbrev': 't',
    'id': 'P2175',
    'rev_id': 'P2176'}

edge_info['GENETIC_ASSOCIATION'] = {
    'abbrev': 'a',
    'id': 'P2293'}

edge_info['HAS_ACTIVE_INGREDIENT'] = {
    'abbrev': 'ai',
    'id': 'P3781'}

edge_info['HAS_CAUSE'] = {
    'abbrev': 'hc',
    'id': 'P828'}

edge_info['HAS_PART'] = {
    'abbrev': 'hp',
    'id': 'P527'}

edge_info['MOLECULAR_FUNCTION'] = {
    'abbrev': 'mf',
    'id': 'P680'}

edge_info['NEGATIVE_DIAGNOSTIC_PREDICTOR'] = {
    'abbrev': 'nd',
    'id': 'P3357'}

edge_info['NEGATIVE_THERAPEUTIC_PREDICTOR'] = {
    'abbrev': 'nt',
    'id': 'P3355'}

edge_info['PHYSICALLY_INTERACTS_WITH'] = {
    'abbrev': 'iw',
    'id': 'P129'}

edge_info['POSITIVE_DIAGNOSTIC_PREDICTOR'] = {
    'abbrev': 'pd',
    'id': 'P3356'}

edge_info['POSITIVE_THERAPEUTIC_PREDICTOR'] = {
    'abbrev': 'pt',
    'id': 'P3354'}

edge_info['SUBCLASS_OF'] = {
    'abbrev': 's',
    'id': 'P279'}

edge_info['SYMPTOMS'] = {
    'abbrev': 'sy',
    'id': 'P780'}

edge_info['MEDICAL_SPECIALTY'] = {
    'abbrev': 'ms',
    'id': 'P1995'}

edge_info['SIGNIFICANT_DRUG_INTERACTION'] = {
    'abbrev': 'di',
    'id': 'P769'}

edge_info['AFFLICTS'] = {
    'abbrev': 'af',
    'id': 'P689'}

edge_info['HAS_ROLE'] = {
    'abbrev': 'r',
    'id': 'P2868'}

edge_info['THERAPEUTIC_AREA'] = {
    'abbrev': 'ta',
    'id': 'P4044'}

edge_info['ANATOMICAL_LOCATION'] = {
    'abbrev': 'l',
    'id': 'P927'}

# %%
node_abbreviations = {k: v['abbrev'] for k, v in node_info.items()}
edge_abbreviations = {k: v['abbrev'] for k, v in edge_info.items()}

# %%
node_abv_to_full = {v: k for k, v in node_abbreviations.items()}
edge_abv_to_full = {v: k for k, v in edge_abbreviations.items()}

# %% [markdown]
# ## Generate queries for the edges

# %%
import sys
sys.path.append('../../hetnet-ml/src/')
import graph_tools as gt

# %%
def generate_instance_tag(qname, n_id):
    return "\n    {n} wdt:P31|wdt:P279 wd:{n_id} .".format(n=qname, n_id=n_id)

def to_query_name(name):
    return '?'+name.lower().replace(' ', '_').replace('-', '')

# %%
def build_query_from_abbrev(abbrev, target=None):
    # Split the edge abbreviation in to subject, predicate, object
    s_abv, p_abv, o_abv = gt.parse_edge_abbrev(abbrev)
    
    # Get the full versions of names
    s_name = node_abv_to_full[s_abv]
    p_name = edge_abv_to_full[p_abv]
    o_name = node_abv_to_full[o_abv]
    
    # Sanitize names for query purposes
    s_qname = to_query_name(s_name)
    o_qname = to_query_name(o_name)
    
    # Need to differentiate start and end if self referential edge
    if s_qname == o_qname:
        s_qname += '1'
        o_qname += '2'
    
    # Get the proper return types
    query_text = "SELECT DISTINCT {s} {s}Label {o} {o}Label".format(s=s_qname, o=o_qname)
    query_text += "\nWHERE {"
    
    return_types = {o_name}
    
    # Build the appropriate info to get the correct subject and object node-types
    # Use set so not repeated in cases of self-referential edges
    for name, qname in [(s_name, s_qname), (o_name, o_qname)]:
        if node_info[name]['id']:
            query_text += '\n\n    # Initial typing for {}'.format(name)
            query_text += generate_instance_tag(qname, node_info[name]['id'])
            return_types.update({name})
    
        # Get any qualifiers for subjects and objects
        for qual in node_info[name].get('qualifiers', []):
            query_text += '\n    # Qualifier for {}'.format(name)
            query_text += generate_qualifier(qual, return_types=return_types)
            # Ensure there isn't the same nodetype definition multiple times
            # E.G. ?gene wdt:P31|wdt:P279 wd:wd:Q7187 # ?gene subclass/instace of Gene
            return_types.update({qual['s'], qual['o']})
                
    # Allows for changing of the target of an edge... for example if we want 
    # Sequnce Variant - variant of - Protein... SV's only go to Genes, so we can use 
    # SV - v - Gene - enc - Pro to get the relationship... 
    # Qualifiers in the protein definito handle the Gene-enc-Pro relationship, but the Target
    # variable handles the fact that SVs point to genes
    if target:
        o_qname = to_query_name(target)
    
    # The actual edge we're interested in
    query_text += "\n\n    # Edge of interest {s} {p} {o}".format(s=s_name, p=p_name, o=o_name)
    
    # Some edges are bi-directonal e.g. drug-used-for-treatment and medical-condition-treated
    # Get edges in eitehr dircetion
    rev_id = edge_info[p_name].get('rev_id', None)
    if rev_id is not None:
        query_text += "\n    {{ {s} wdt:{p} {o} }}".format(s=s_qname, p=edge_info[p_name]['id'], o=o_qname)
        query_text += "\n    UNION {{ {s} wdt:{p} {o} }}".format(s=o_qname, p=rev_id, o=s_qname)
    else:
        query_text += "\n    {s} wdt:{p} {o} ".format(s=s_qname, p=edge_info[p_name]['id'], o=o_qname)

    
    # Make sure labels return in english
    query_text += '\n\n    SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }\n}'

    return query_text

# %%
def generate_qualifier(qual, return_types=None):
    node_q_names = {}
    
    for node in ['s', 'o']:
        node_name = qual[node]
        if node_name in node_info.keys():
            node_q_names[node] = to_query_name(node_name)
        elif node_name is None:
            node_q_names[node] = '?na'
        else:    
            node_q_names[node] = 'wd:'+node_name

    qual_out = ''
    
    # if we have true node-types, we need to ensure they're used
    for semtype, qname in node_q_names.items():
        if not qname.startswith('wd:') and qual[semtype] not in return_types and qname is not '?na':
            qual_out += generate_instance_tag(qname, node_info[qual[semtype]]['id'])        
    
    # Negative qualifiers need to filter out edges
    if qual['not']:
        qual_out += '\n    FILTER NOT EXISTS {{ {s} wdt:{p} {o} }} .'.format(s=node_q_names['s'], 
                                                                            p=qual['p'], o=node_q_names['o'])
    # Otherwise add the edges
    else:
        qual_out += '\n    {s} wdt:{p} {o} .'.format(s=node_q_names['s'], 
                                                    p=qual['p'], o=node_q_names['o'])
    
    return qual_out

# %%
hetnet_edges = [
    {'abbrev': 'CdiC'},
    {'abbrev': 'CtD'},
    {'abbrev': 'PPaiC'},
    {'abbrev': 'CHhcC'},
    {'abbrev': 'PWhpC'},
    {'abbrev': 'PiwC'},
    {'abbrev': 'VntC'},
    {'abbrev': 'VptC'},
    {'abbrev': 'DaP', 'target': 'Gene'},
    {'abbrev': 'DaG'},
    {'abbrev': 'DsyS'},
    {'abbrev': 'DmsMS'},
    {'abbrev': 'CHsyS'},
    {'abbrev': 'CHsyD'},
    {'abbrev': 'VndD'},
    {'abbrev': 'VpdD'},
    {'abbrev': 'VvP', 'target': 'Gene'},
    {'abbrev': 'VvG'},
    {'abbrev': 'PWhpP', 'target': 'Gene'},
    {'abbrev': 'PWhpG'},
    {'abbrev': 'PccCC'},
    {'abbrev': 'PbpBP'},
    {'abbrev': 'PmfMF'},
    {'abbrev': 'PhpPD'},
    {'abbrev': 'PhpSS'},
    {'abbrev': 'PsPF'},
    {'abbrev': 'PhpBS'},
    {'abbrev': 'PhpAS'},
    {'abbrev': 'PhpSM'},
    {'abbrev': 'PPtaD'},
    {'abbrev': 'CrCR'},
    {'abbrev': 'DlA'},
    {'abbrev': 'CHafA'},
    {'abbrev': 'CtCH'}
]

# %%
queries = [build_query_from_abbrev(**g_edge) for g_edge in hetnet_edges]

# %% [markdown]
# ## Run the queries

# %%
import functools
from wikidataintegrator.wdi_core import WDItemEngine
from tqdm import tqdm

endpoint='http://avalanche.scripps.edu:9999/bigdata/sparql'

def parse_result_uris(result):
    for c in result:
        if 'Label' not in c:
            idx = result[c].str.startswith('http://www.wikidata.org/entity')
            result[c][idx] = result[c][idx].str.split('/', expand=True).iloc[:,-1]
    return result.drop_duplicates()

query_func = functools.partial(WDItemEngine.execute_sparql_query, endpoint=endpoint, as_dataframe=True)

def execute_sparql_query(query_text):
    # Enforce the proper column order
    col_order = query_text.split('\n')[0].split(' ?')[1:]
    return parse_result_uris(query_func(query_text))[col_order]

# %%
res = {e['abbrev']: execute_sparql_query(q) for e, q in tqdm(zip(hetnet_edges, queries), total=len(hetnet_edges))}
# Out:
# 100%|██████████| 34/34 [03:33<00:00,  6.27s/it]

# %%
# How many total edges retrieved?
'{:,} raw edges'.format(sum(len(v) for v in res.values()))
# Out:
# '460,776 raw edges'

# %% [markdown]
# ## Two potnetial issues to look into...
#
# 1. Self-referential edges...
#     These edges may contain `node1 - node2` edges as well as `node2 - node1` edges
#
# 2. Multi or miss-typed nodes...
#     Some node IDs may show up as multiple types... especially chemical roles and chemical compounds.

# %%
node_ids = dict()
id_to_name = dict()
self_ref = set()

for e, r in res.items():
    n_types = [c for c in r.columns if not c.endswith('Label')]
    
    for nt in n_types:
        if nt.endswith('1') or nt.endswith('2'):
            node_type = nt[:-1]
            self_ref.add(e)
        else:
            node_type = nt
    
        if node_type in node_ids:
            node_ids[node_type].update(set(r[nt]))
        else:
            node_ids[node_type] = set(r[nt])
    
        id_to_name.update(r.set_index(nt)[nt+'Label'].to_dict())

# %% [markdown]
# ### Fix the Self-Ref edges where forward and backward edges may be duplicated

# %%
len(res.keys())
# Out:
# 34

# %%
fixed = dict()

for kind in tqdm(self_ref):
    
    # no need to worry about forward vs reverse in directed edges
    if '>' in kind or '<' in kind:
        continue
    
    # Only look at 1 kind of edge at a time
    this_edges = res[kind]
    col_names = this_edges.columns
    
    edge_ids = set()
    
    for row in this_edges.itertuples():
        # Grab the edge ID, sorting, so lowest ID first:
        #     If both 'Q00001 -- Q00002' and 'Q00002 -- Q00001' exist, effectively standarizes to 
        #     'Q00001 -- Q00002'
        edge_id = tuple(sorted([row[1], row[3]]))
        edge_ids.add(edge_id)

    start_ids = []
    start_names = []
    end_ids = []
    end_names = []

        
    for edge_id in edge_ids:
        start_ids.append(edge_id[0])
        start_names.append(id_to_name[edge_id[0]])
        end_ids.append(edge_id[1])
        end_names.append(id_to_name[edge_id[1]])
    
    fixed[kind] = pd.DataFrame({col_names[0]: start_ids, col_names[1]: start_names, col_names[2]: end_ids, col_names[3]: end_names})
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 85.04it/s]

# %%
# Check an arbitrary edge that was fixed
k = next(iter(fixed.keys()))
print('Edge direction standardization results for {}'.format(k))
print('Before: {:,}\tAfter: {:,}'.format(len(res[k]), len(fixed[k])))
# Out:
# Edge direction standardization results for CdiC
# Before: 1,807	After: 1,105

# %%
# numver of unique node ids
'{:,} nodes (possibly some duplicats across type)'.format(sum(len(v) for v in node_ids.values()))
# Out:
# '66,677 nodes (possibly some duplicats across type)'

# %%
for k, v in node_ids.items():
    print('{} : {}'.format(k, len(v)))
# Out:
# compound : 8089
# disease : 6207
# pharmaceutical_product : 2301
# chemical_hazard : 689
# biological_pathway : 563
# protein : 22742
# sequence_variant : 1758
# gene : 215
# symptom : 253
# medical_specialty : 69
# cellular_component : 1729
# biological_process : 12126
# molecular_function : 4267
# protein_domain : 4296
# supersecondary_structure : 455
# protein_family : 16
# binding_site : 55
# active_site : 89
# structural_motif : 108
# chemical_role : 494
# anatomical_structure : 156

# %%
total = set()
for v in node_ids.values():
    total = total.union(v) 
'{:,} unique nodes ids'.format(len(total))
# Out:
# '66,673 unique nodes ids'

# %%
'{:,} total nodes with multiple types'.format(sum(len(v) for v in node_ids.values()) - len(total))
# Out:
# '4 total nodes with multiple types'

# %% [markdown]
# It will be easier to address these node issues once we've got the networks formatted into the hetnet standard
#
# ## Format Nodes into Hetnet

# %%
nodes = []
for k, v in node_ids.items():
    curr_nodes = pd.DataFrame({'id': list(v), 'label': len(v)*[k]})
    curr_nodes['name'] = curr_nodes['id'].map(id_to_name)
    nodes.append(curr_nodes)
nodes = pd.concat(nodes).reset_index(drop=True)

# %%
nodes[nodes.duplicated(keep=False, subset=['id'])].sort_values('id')
# Out:
#              id               label                           name
# 1413    Q127060            compound                     folic acid
# 66431   Q127060       chemical_role                     folic acid
# 8583    Q408089             disease              mercury poisoning
# 16979   Q408089     chemical_hazard              mercury poisoning
# 2665    Q414964            compound  Vasoactive intestinal peptide
# 32949   Q414964             protein  Vasoactive intestinal peptide
# 14077  Q7860879             disease       type IV hypersensitivity
# 50473  Q7860879  biological_process       type IV hypersensitivity

# %%
label_map = {to_query_name(k)[1:]: k for k in node_info.keys()}

# %%
nodes['label'] = nodes['label'].map(label_map)

# %%
nodes.head(10)
# Out:
#           id     label                    name
# 0  Q27107534  Compound   nitroblue tetrazolium
# 1  Q27102886  Compound  (S)-3-aminoisobutyrate
# 2   Q4836835  Compound                BW723C86
# 3   Q2112916  Compound              propachlor
# 4    Q411092  Compound     pyrophosphoric acid
# 5   Q6823517  Compound             metergoline
# 6   Q1187179  Compound     Denileukin diftitox
# 7    Q424390  Compound         cyclopentadiene
# 8    Q413598  Compound              prilocaine
# 9  Q27265984  Compound            carbizocaine

# %% [markdown]
# ## Format Edges into Hetnet
#
# The original design feature was to merege `Genes` and `Proetins` acrsos the `ENCODES` edge to create one metanode `Gene` that essentially means Gene or Gene Product.  We will start that process when building the edges

# %%
edges = []

for k, v in res.items():
    if k in fixed.keys():
        v = fixed[k]
    
    
    col_names = v.columns
    keep_cols = [c for c in col_names if not c.endswith('Label')]
    col_name_map = {keep_cols[0]: 'start_id', keep_cols[1]: 'end_id'}
    
    # Replace Proteins with Genes, to merge the protein and gene metanodes
    parsed_edge = gt.parse_edge_abbrev(k)
    if 'P' in parsed_edge:
        idx = parsed_edge.index('P')
        parsed_edge = list(parsed_edge)
        parsed_edge[idx] = 'G'
        k = ''.join(parsed_edge)
    
    v = v[keep_cols].rename(columns=col_name_map)
    v['type'] = edge_abv_to_full[parsed_edge[1]] + '_' + k
    
    edges.append(v)
edges = pd.concat(edges).reset_index(drop=True)

# %%
edges['type'].value_counts()
# Out:
# BIOLOGICAL_PROCESS_GbpBP               161545
# CELL_COMPONENT_GccCC                    99926
# MOLECULAR_FUNCTION_GmfMF                87111
# HAS_PART_GhpPD                          30490
# HAS_PART_PWhpG                          24876
# HAS_ROLE_CrCR                            9931
# MEDICAL_SPECIALTY_DmsMS                  6533
# TREATS_CtD                               5217
# HAS_PART_GhpSS                           4130
# PHYSICALLY_INTERACTS_WITH_GiwC           3645
# SYMPTOMS_CHsyS                           3450
# HAS_PART_PWhpC                           3384
# GENETIC_ASSOCIATION_DaG                  3043
# VARIANT_OF_VvG                           2528
# HAS_PART_GhpSM                           2238
# HAS_ACTIVE_INGREDIENT_PPaiC              2162
# SYMPTOMS_CHsyD                           1481
# AFFLICTS_CHafA                           1170
# THERAPEUTIC_AREA_PPtaD                   1124
# SIGNIFICANT_DRUG_INTERACTION_CdiC        1105
# HAS_PART_GhpAS                           1046
# HAS_PART_GhpBS                            852
# POSITIVE_THERAPEUTIC_PREDICTOR_VptC       721
# ANATOMICAL_LOCATION_DlA                   704
# HAS_CAUSE_CHhcC                           597
# NEGATIVE_THERAPEUTIC_PREDICTOR_VntC       541
# SYMPTOMS_DsyS                             372
# POSITIVE_DIAGNOSTIC_PREDICTOR_VpdD         78
# TREATS_CtCH                                47
# SUBCLASS_OF_GsPF                           21
# NEGATIVE_DIAGNOSTIC_PREDICTOR_VndD          6
# Name: type, dtype: int64

# %%
# merge the genes and proteins in the nodes file
idx = nodes.query('label == "Protein"').index
nodes.loc[idx, 'label'] = 'Gene'

# %%
print(build_query_from_abbrev('VndD'))
# Out:
# SELECT DISTINCT ?sequence_variant ?sequence_variantLabel ?disease ?diseaseLabel
# WHERE {
#
#     # Initial typing for Disease
#     ?disease wdt:P31|wdt:P279 wd:Q12136 .
#
#     # Edge of interest Sequence Variant NEGATIVE_DIAGNOSTIC_PREDICTOR Disease
#     ?sequence_variant wdt:P3357 ?disease
#
#     SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
# }

# %%
nodes['label'].value_counts()
# Out:
# Gene                         22957
# Biological Process           12126
# Compound                      8089
# Disease                       6207
# Protein Domain                4296
# Molecular Function            4267
# Pharmaceutical Product        2301
# Sequence Variant              1758
# Cellular Component            1729
# Chemical Hazard                689
# Biological Pathway             563
# Chemical Role                  494
# Super-Secondary Structure      455
# Symptom                        253
# Anatomical Structure           156
# Structural Motif               108
# Active Site                     89
# Medical Specialty               69
# Binding Site                    55
# Protein Family                  16
# Name: label, dtype: int64

# %% [markdown]
# ## Now Back to problem 2, nodes that are duplicated across two different Node Types

# %%
duplicated_nodes = nodes[nodes.duplicated(keep=False, subset=['id'])]['id'].unique()

# %%
duplicated_nodes
# Out:
# array(['Q127060', 'Q414964', 'Q408089', 'Q7860879'], dtype=object)

# %%
combo = gt.combine_nodes_and_edges(nodes, edges)

# %%
# See a representitive edge of each type to ensure everything looks ok...
combo.drop_duplicates(subset='type')
# Out:
#          start_id     end_id                                 type  \
# 0         Q244408    Q407431    SIGNIFICANT_DRUG_INTERACTION_CdiC
# 1105      Q408801    Q170990                           TREATS_CtD
# 6322    Q47521989    Q409251          HAS_ACTIVE_INGREDIENT_PPaiC
# 8484    Q21175000    Q417316                      HAS_CAUSE_CHhcC
# 9081    Q44054558  Q27104149                       HAS_PART_PWhpC
# 12465    Q4847907    Q411917       PHYSICALLY_INTERACTS_WITH_GiwC
# 16110   Q28546459     Q18936  NEGATIVE_THERAPEUTIC_PREDICTOR_VntC
# 16651   Q29920046  Q27077182  POSITIVE_THERAPEUTIC_PREDICTOR_VptC
# 17372     Q844935   Q4650352              GENETIC_ASSOCIATION_DaG
# 20415    Q4454701    Q186889                        SYMPTOMS_DsyS
# 20787     Q373822      Q7867              MEDICAL_SPECIALTY_DmsMS
# 27320    Q7030575        Q86                       SYMPTOMS_CHsyS
# 30770   Q21167640   Q1799146                       SYMPTOMS_CHsyD
# 32251   Q27908043    Q264118   NEGATIVE_DIAGNOSTIC_PREDICTOR_VndD
# 32257   Q28429317    Q729735   POSITIVE_DIAGNOSTIC_PREDICTOR_VpdD
# 32335   Q28371415    Q424401                       VARIANT_OF_VvG
# 34863   Q30225387  Q23308049                       HAS_PART_PWhpG
# 59739   Q21139565      Q7868                 CELL_COMPONENT_GccCC
# 159665  Q21108672      Q1057             BIOLOGICAL_PROCESS_GbpBP
# 321210  Q21119889  Q14876109             MOLECULAR_FUNCTION_GmfMF
# 408321  Q21123349  Q24721508                       HAS_PART_GhpPD
# 438811  Q21096420  Q24719556                       HAS_PART_GhpSS
# 442941  Q21105658  Q26916558                     SUBCLASS_OF_GsPF
# 442962   Q2720322  Q24738895                       HAS_PART_GhpBS
# 443814  Q21119234  Q24783188                       HAS_PART_GhpAS
# 444860  Q21115000   Q7948257                       HAS_PART_GhpSM
# 447098  Q29006010    Q123251               THERAPEUTIC_AREA_PPtaD
# 448222    Q415173     Q12187                        HAS_ROLE_CrCR
# 458153      Q2840      Q7891              ANATOMICAL_LOCATION_DlA
# 458857  Q21174786      Q7891                       AFFLICTS_CHafA
# 460027    Q416410  Q21174292                          TREATS_CtCH
#
#                                                start_name  \
# 0                                              diclofenac
# 1105                                            celecoxib
# 6322                                               Phoslo
# 8484                                 nitroethane exposure
# 9081                       Glycolysis and Gluconeogenesis
# 12465                   Cholinergic receptor muscarinic 4
# 16110                                  RB1 OVEREXPRESSION
# 16651                                       IDH2 MUTATION
# 17372                             coronary artery disease
# 20415                                  Taeniasis saginata
# 20787                                     eating disorder
# 27320                                  nicotine poisoning
# 30770                               acrylic acid exposure
# 32251                                         DNMT3A R882
# 32257                                          JAK2 V617F
# 32335                                          EGFR S492R
# 34863                                   Folate Metabolism
# 59739                                          Exportin-1
# 159665  Glycerol-3-phosphate acyltransferase, mitochon...
# 321210                           Kinesin family member 1A
# 408321                        Patched domain containing 1
# 438811             Actin, gamma 2, smooth muscle, enteric
# 442941            Cyclic nucleotide gated channel alpha 2
# 442962                                        Parvalbumin
# 443814      Protein tyrosine phosphatase, receptor type U
# 444860     Protein phosphatase 2 regulatory subunit Bbeta
# 447098                                            Introna
# 448222                                        cefpodoxime
# 458153                                          influenza
# 458857                                Isophorone exposure
# 460027                                         fomepizole
#
#                                                  end_name  \
# 0                                                warfarin
# 1105                                            arthritis
# 6322                                      calcium acetate
# 8484                                          nitroethane
# 9081                                         D-malic acid
# 12465                                      glycopyrrolate
# 16110                                         doxorubicin
# 16651                                          Enasidenib
# 17372   ABO, alpha 1-3-N-acetylgalactosaminyltransfera...
# 20415                                              nausea
# 20787                                          psychiatry
# 27320                                            headache
# 30770                                 irritant dermatitis
# 32251                              acute myeloid leukemia
# 32257                            chronic myeloid leukemia
# 32335                    Epidermal growth factor receptor
# 34863                    Cystathionine-beta-synthase like
# 59739                                                cell
# 159665                                         metabolism
# 321210                                     motor activity
# 408321                              Sterol-sensing domain
# 438811                    Actin/actin-like conserved site
# 442941            Cyclic nucleotide-gated channel alpha-2
# 442962                    EF-Hand 1, calcium-binding site
# 443814          Protein-tyrosine phosphatase, active site
# 444860                                        WD40 repeat
# 447098                                follicular lymphoma
# 448222                                         antibiotic
# 458153                                 respiratory system
# 458857                                 respiratory system
# 460027                           ethylene glycol exposure
#
#                    start_label                  end_label
# 0                     Compound                   Compound
# 1105                  Compound                    Disease
# 6322    Pharmaceutical Product                   Compound
# 8484           Chemical Hazard                   Compound
# 9081        Biological Pathway                   Compound
# 12465                     Gene                   Compound
# 16110         Sequence Variant                   Compound
# 16651         Sequence Variant                   Compound
# 17372                  Disease                       Gene
# 20415                  Disease                    Symptom
# 20787                  Disease          Medical Specialty
# 27320          Chemical Hazard                    Symptom
# 30770          Chemical Hazard                    Disease
# 32251         Sequence Variant                    Disease
# 32257         Sequence Variant                    Disease
# 32335         Sequence Variant                       Gene
# 34863       Biological Pathway                       Gene
# 59739                     Gene         Cellular Component
# 159665                    Gene         Biological Process
# 321210                    Gene         Molecular Function
# 408321                    Gene             Protein Domain
# 438811                    Gene  Super-Secondary Structure
# 442941                    Gene             Protein Family
# 442962                    Gene               Binding Site
# 443814                    Gene                Active Site
# 444860                    Gene           Structural Motif
# 447098  Pharmaceutical Product                    Disease
# 448222                Compound              Chemical Role
# 458153                 Disease       Anatomical Structure
# 458857         Chemical Hazard       Anatomical Structure
# 460027                Compound            Chemical Hazard

# %%
#take a look at some of these problematic nodes
pd.concat([combo.query('start_id in @duplicated_nodes').drop_duplicates(subset=['start_id','type']),
combo.query('end_id in @duplicated_nodes').drop_duplicates(subset=['end_id','type'])])
# Out:
#          start_id     end_id                      type  \
# 4573      Q127060   Q2070695                TREATS_CtD
# 20434     Q408089        Q86             SYMPTOMS_DsyS
# 24048    Q7860879    Q101929   MEDICAL_SPECIALTY_DmsMS
# 25153     Q408089   Q2861470   MEDICAL_SPECIALTY_DmsMS
# 27354     Q408089        Q86            SYMPTOMS_CHsyS
# 30775     Q408089   Q1054718            SYMPTOMS_CHsyD
# 63322     Q414964   Q3824358      CELL_COMPONENT_GccCC
# 173242    Q414964  Q14758909  BIOLOGICAL_PROCESS_GbpBP
# 323045    Q414964  Q14819840  MOLECULAR_FUNCTION_GmfMF
# 423721    Q414964  Q24772514            HAS_PART_GhpPD
# 451301    Q127060    Q183206             HAS_ROLE_CrCR
# 454250    Q414964  Q12537482             HAS_ROLE_CrCR
# 459110    Q408089      Q7891            AFFLICTS_CHafA
# 2230      Q421239    Q408089                TREATS_CtD
# 9098    Q44054573    Q127060            HAS_PART_PWhpC
# 35133   Q30225404    Q414964            HAS_PART_PWhpG
# 164607  Q21101536   Q7860879  BIOLOGICAL_PROCESS_GbpBP
# 449444    Q415220    Q127060             HAS_ROLE_CrCR
# 460042    Q421239    Q408089               TREATS_CtCH
#
#                                         start_name  \
# 4573                                    folic acid
# 20434                            mercury poisoning
# 24048                     type IV hypersensitivity
# 25153                            mercury poisoning
# 27354                            mercury poisoning
# 30775                            mercury poisoning
# 63322                Vasoactive intestinal peptide
# 173242               Vasoactive intestinal peptide
# 323045               Vasoactive intestinal peptide
# 423721               Vasoactive intestinal peptide
# 451301                                  folic acid
# 454250               Vasoactive intestinal peptide
# 459110                           mercury poisoning
# 2230                               D-penicillamine
# 9098    One carbon metabolism and related pathways
# 35133                       IL-6 signaling pathway
# 164607                      GATA binding protein 3
# 449444                                  pemetrexed
# 460042                             D-penicillamine
#
#                                             end_name         start_label  \
# 4573                               macrocytic anemia       Chemical Role
# 20434                                       headache     Chemical Hazard
# 24048                                     immunology  Biological Process
# 25153                             emergency medicine     Chemical Hazard
# 27354                                       headache     Chemical Hazard
# 30775                                 kidney disease     Chemical Hazard
# 63322                                  intracellular                Gene
# 173242  G-protein coupled receptor signaling pathway                Gene
# 323045                 neuropeptide hormone activity                Gene
# 423721                     Glucagon/GIP/secretin/VIP                Gene
# 451301                                     vitamin B       Chemical Role
# 454250                             vasodilator agent                Gene
# 459110                            respiratory system     Chemical Hazard
# 2230                               mercury poisoning            Compound
# 9098                                      folic acid  Biological Pathway
# 35133                  Vasoactive intestinal peptide  Biological Pathway
# 164607                      type IV hypersensitivity                Gene
# 449444                                    folic acid            Compound
# 460042                             mercury poisoning            Compound
#
#                    end_label
# 4573                 Disease
# 20434                Symptom
# 24048      Medical Specialty
# 25153      Medical Specialty
# 27354                Symptom
# 30775                Disease
# 63322     Cellular Component
# 173242    Biological Process
# 323045    Molecular Function
# 423721        Protein Domain
# 451301         Chemical Role
# 454250         Chemical Role
# 459110  Anatomical Structure
# 2230         Chemical Hazard
# 9098           Chemical Role
# 35133                   Gene
# 164607    Biological Process
# 449444         Chemical Role
# 460042       Chemical Hazard

# %%
# examining the above results, it looks like this is the mapping we desire
resolved_multiples = {
    'Q414964': 'Gene',
    'Q127060': 'Compound', 
    'Q7860879': 'Biological Process',
    'Q408089': 'Chemical Hazard'
}

# %%
id_to_label = nodes.set_index('id')['label'].to_dict()

# %%
nodes['label'] = nodes['id'].map(lambda i: resolved_multiples.get(i, id_to_label[i]))

# %%
print(len(nodes))
nodes = nodes.drop_duplicates().reset_index(drop=True)
print(len(nodes))
# Out:
# 66677
# 66673

# %%
combo = gt.combine_nodes_and_edges(nodes, edges)

# %%
combo.head(2)
# Out:
#   start_id   end_id                               type  start_name  \
# 0  Q244408  Q407431  SIGNIFICANT_DRUG_INTERACTION_CdiC  diclofenac
# 1  Q425295    Q7739  SIGNIFICANT_DRUG_INTERACTION_CdiC   cisapride
#
#            end_name start_label end_label
# 0          warfarin    Compound  Compound
# 1  arsenic trioxide    Compound  Compound

# %%
combo['edge_abv'] = combo['type'].apply(lambda t: t.split('_')[-1])
combo['actual_start'] = combo['edge_abv'].apply(lambda a: node_abv_to_full[gt.parse_edge_abbrev(a)[0]])
combo['actual_end'] = combo['edge_abv'].apply(lambda a: node_abv_to_full[gt.parse_edge_abbrev(a)[2]])

# %%
bad_edge = combo.query('start_label != actual_start or end_label != actual_end')
bad_edge
# Out:
#         start_id     end_id                     type  \
# 2230     Q421239    Q408089               TREATS_CtD
# 20434    Q408089        Q86            SYMPTOMS_DsyS
# 20490    Q408089    Q209583            SYMPTOMS_DsyS
# 20494    Q408089   Q3002092            SYMPTOMS_DsyS
# 20503    Q408089    Q188008            SYMPTOMS_DsyS
# 20591    Q408089    Q223907            SYMPTOMS_DsyS
# 20592    Q408089    Q254327            SYMPTOMS_DsyS
# 20594    Q408089    Q693058            SYMPTOMS_DsyS
# 20631    Q408089  Q21117327            SYMPTOMS_DsyS
# 20633    Q408089  Q18343527            SYMPTOMS_DsyS
# 20638    Q408089  Q21111972            SYMPTOMS_DsyS
# 20667    Q408089      Q9690            SYMPTOMS_DsyS
# 20725    Q408089     Q35805            SYMPTOMS_DsyS
# 20742    Q408089   Q2266426            SYMPTOMS_DsyS
# 20746    Q408089    Q633403            SYMPTOMS_DsyS
# 20750    Q408089    Q623289            SYMPTOMS_DsyS
# 24048   Q7860879    Q101929  MEDICAL_SPECIALTY_DmsMS
# 25153    Q408089   Q2861470  MEDICAL_SPECIALTY_DmsMS
# 449444   Q415220    Q127060            HAS_ROLE_CrCR
# 449493   Q421072    Q127060            HAS_ROLE_CrCR
# 449496   Q422232    Q127060            HAS_ROLE_CrCR
# 449498   Q422665    Q127060            HAS_ROLE_CrCR
# 454250   Q414964  Q12537482            HAS_ROLE_CrCR
# 455482   Q414964  Q50377190            HAS_ROLE_CrCR
# 455859   Q414964  Q50377202            HAS_ROLE_CrCR
#
#                            start_name                   end_name  \
# 2230                  D-penicillamine          mercury poisoning
# 20434               mercury poisoning                   headache
# 20490               mercury poisoning                tachycardia
# 20494               mercury poisoning           abdominal cramps
# 20503               mercury poisoning                    dyspnea
# 20591               mercury poisoning                     tremor
# 20592               mercury poisoning                   anorexia
# 20594               mercury poisoning                 chest pain
# 20631               mercury poisoning                 indecision
# 20633               mercury poisoning  Gastrointestinal distress
# 20638               mercury poisoning             eye irritation
# 20667               mercury poisoning                    fatigue
# 20725               mercury poisoning                      cough
# 20742               mercury poisoning         visual disturbance
# 20746               mercury poisoning                   weakness
# 20750               mercury poisoning                  dysphagia
# 24048        type IV hypersensitivity                 immunology
# 25153               mercury poisoning         emergency medicine
# 449444                     pemetrexed                 folic acid
# 449493                  pyrimethamine                 folic acid
# 449496                   methotrexate                 folic acid
# 449498                   trimethoprim                 folic acid
# 454250  Vasoactive intestinal peptide          vasodilator agent
# 455482  Vasoactive intestinal peptide      neuroprotective agent
# 455859  Vasoactive intestinal peptide    Gastrointestinal Agents
#
#                start_label          end_label edge_abv actual_start  \
# 2230              Compound    Chemical Hazard      CtD     Compound
# 20434      Chemical Hazard            Symptom     DsyS      Disease
# 20490      Chemical Hazard            Symptom     DsyS      Disease
# 20494      Chemical Hazard            Symptom     DsyS      Disease
# 20503      Chemical Hazard            Symptom     DsyS      Disease
# 20591      Chemical Hazard            Symptom     DsyS      Disease
# 20592      Chemical Hazard            Symptom     DsyS      Disease
# 20594      Chemical Hazard            Symptom     DsyS      Disease
# 20631      Chemical Hazard            Symptom     DsyS      Disease
# 20633      Chemical Hazard            Symptom     DsyS      Disease
# 20638      Chemical Hazard            Symptom     DsyS      Disease
# 20667      Chemical Hazard            Symptom     DsyS      Disease
# 20725      Chemical Hazard            Symptom     DsyS      Disease
# 20742      Chemical Hazard            Symptom     DsyS      Disease
# 20746      Chemical Hazard            Symptom     DsyS      Disease
# 20750      Chemical Hazard            Symptom     DsyS      Disease
# 24048   Biological Process  Medical Specialty    DmsMS      Disease
# 25153      Chemical Hazard  Medical Specialty    DmsMS      Disease
# 449444            Compound           Compound     CrCR     Compound
# 449493            Compound           Compound     CrCR     Compound
# 449496            Compound           Compound     CrCR     Compound
# 449498            Compound           Compound     CrCR     Compound
# 454250                Gene      Chemical Role     CrCR     Compound
# 455482                Gene      Chemical Role     CrCR     Compound
# 455859                Gene      Chemical Role     CrCR     Compound
#
#                actual_end
# 2230              Disease
# 20434             Symptom
# 20490             Symptom
# 20494             Symptom
# 20503             Symptom
# 20591             Symptom
# 20592             Symptom
# 20594             Symptom
# 20631             Symptom
# 20633             Symptom
# 20638             Symptom
# 20667             Symptom
# 20725             Symptom
# 20742             Symptom
# 20746             Symptom
# 20750             Symptom
# 24048   Medical Specialty
# 25153   Medical Specialty
# 449444      Chemical Role
# 449493      Chemical Role
# 449496      Chemical Role
# 449498      Chemical Role
# 454250      Chemical Role
# 455482      Chemical Role
# 455859      Chemical Role

# %%
# Becasue combo is made by merging the nodes onto the edges, the index is constant between the two DataFrames
edges = edges.drop(bad_edge.index).reset_index(drop=True)

# %% [markdown]
# ## Write out results

# %%
out_dir = '../2_pipeline/00_hetnet_design_and_build/out'

if not os.path.exists(out_dir):
    os.makedirs(out_dir)

gt.add_colons(nodes).to_csv(os.path.join(out_dir, 'nodes.csv'), index=False)
gt.add_colons(edges).to_csv(os.path.join(out_dir, 'edges.csv'), index=False)

json.dump(node_info, open(os.path.join(out_dir, 'node_info.json'), 'w'), sort_keys=True, indent=2)
json.dump(edge_info, open(os.path.join(out_dir, 'edge_info.json'), 'w'), sort_keys=True, indent=2)
json.dump(hetnet_edges, open(os.path.join(out_dir, 'hetnet_edges.json'), 'w'), sort_keys=True, indent=2)
